# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
print ("Hello")
# Out:
# Hello

# %%
import pandas as pd

# %%
print ("Environment ready ")
# Out:
# Environment ready

# %%
data = pd.read_csv("../data/Loan_default.csv")
data.head()
# Out:
#        LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0  I38PQUQS96   56   85994       50587          520              80
# 1  HPSK72WA7R   69   50432      124440          458              15
# 2  C1OZ6DPJ8Y   46   84208      129188          451              26
# 3  V2KKSFM3UN   32   31713       44799          743               0
# 4  EY08JDHTZP   60   20437        9139          633               8
#
#    NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# 0               4         15.23        36      0.44   Bachelor's
# 1               1          4.81        60      0.68     Master's
# 2               3         21.17        24      0.31     Master's
# 3               3          7.07        24      0.23  High School
# 4               4          6.51        48      0.73   Bachelor's
#
#   EmploymentType MaritalStatus HasMortgage HasDependents LoanPurpose  \
# 0      Full-time      Divorced         Yes           Yes       Other
# ...

# %%
data.shape
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255347 entries, 0 to 255346
# Data columns (total 18 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   LoanID          255347 non-null  object
#  1   Age             255347 non-null  int64
#  2   Income          255347 non-null  int64
#  3   LoanAmount      255347 non-null  int64
#  4   CreditScore     255347 non-null  int64
#  5   MonthsEmployed  255347 non-null  int64
#  6   NumCreditLines  255347 non-null  int64
#  7   InterestRate    255347 non-null  float64
#  8   LoanTerm        255347 non-null  int64
#  9   DTIRatio        255347 non-null  float64
#  10  Education       255347 non-null  object
#  11  EmploymentType  255347 non-null  object
#  12  MaritalStatus   255347 non-null  object
#  13  HasMortgage     255347 non-null  object
#  14  HasDependents   255347 non-null  object
#  15  LoanPurpose     255347 non-null  object
# ...

# %%
data.columns
# Out:
# Index(['LoanID', 'Age', 'Income', 'LoanAmount', 'CreditScore',
#        'MonthsEmployed', 'NumCreditLines', 'InterestRate', 'LoanTerm',
#        'DTIRatio', 'Education', 'EmploymentType', 'MaritalStatus',
#        'HasMortgage', 'HasDependents', 'LoanPurpose', 'HasCoSigner',
#        'Default'],
#       dtype='object')

# %%
data.head(10)
# Out:
#        LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0  I38PQUQS96   56   85994       50587          520              80
# 1  HPSK72WA7R   69   50432      124440          458              15
# 2  C1OZ6DPJ8Y   46   84208      129188          451              26
# 3  V2KKSFM3UN   32   31713       44799          743               0
# 4  EY08JDHTZP   60   20437        9139          633               8
# 5  A9S62RQ7US   25   90298       90448          720              18
# 6  H8GXPAOS71   38  111188      177025          429              80
# 7  0HGZQKJ36W   56  126802      155511          531              67
# 8  1R0N3LGNRJ   36   42053       92357          827              83
# 9  CM9L1GTT2P   40  132784      228510          480             114
#
#    NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# 0               4         15.23        36      0.44   Bachelor's
# 1               1          4.81        60      0.68     Master's
# ...

# %%
data["Default"].value_counts()
# Out:
# Default
# 0    225694
# 1     29653
# Name: count, dtype: int64

# %%
data["Default"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Default'>

# %%
data["Default"].value_counts().plot(kind="bar")
plt.title("Loan Default Distribution")
plt.show()

# %%
data.groupby("Default")["CreditScore"].mean()
# Out:
# Default
# 0    576.232270
# 1    559.286143
# Name: CreditScore, dtype: float64

# %%
data[data["Default"]==0]["CreditScore"].hist(bins=30)
plt.title("Credit Score Distribution (No Default)")
plt.show()

# %%
data.groupby("Default")["Income"].mean()
# Out:
# Default
# 0    83899.165995
# 1    71844.722659
# Name: Income, dtype: float64

# %%
data[data["Default"]==1]["CreditScore"].hist(bins=30)
plt.title("Credit Score Distribution (No Default)")
plt.show()

# %%
data.groupby("Default")["Income"].mean()
# Out:
# Default
# 0    83899.165995
# 1    71844.722659
# Name: Income, dtype: float64

# %%
data.groupby("Default")["LoanAmount"].mean()
# Out:
# Default
# 0    125353.656017
# 1    144515.311469
# Name: LoanAmount, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
corr = data.select_dtypes(include='number').corr()
plt.figure(figsize = (10,6))
sns.heatmap(corr, annot = True, cmap="coolwarm")
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='default', data=df)
plt.title("Loan Default Distribution")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 4
#       1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
# ----> 4 sns.countplot(x='default', data=df)
#       5 plt.title("Loan Default Distribution")
#       6 plt.show()
#
# NameError: name 'df' is not defined

# %%
x = data[['Age', 'Income', 'LoanAmount', 'CreditScore', 
          'MonthsEmployed', 'NumCreditLines', 'InterestRate', 
          'LoanTerm', 'DTIRatio']]
y = data['Default']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(max_iter=1000)
model.fit(x_train, y_train)
# Out:
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 1000 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=1000).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=1000)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(max_iter=1000)
model.fit(x_train_scaled, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
predictions = model.predict(x_test_scaled)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, predictions)
print("Model Accuracy:", accuracy)
# Out:
# Model Accuracy: 0.8848834932445663

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, predictions)

plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     45170
#            1       0.55      0.02      0.04      5900
#
#     accuracy                           0.88     51070
#    macro avg       0.72      0.51      0.49     51070
# weighted avg       0.85      0.88      0.83     51070

# %%
cm = confusion_matrix(y_test, predictions)

plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")

plt.savefig("confusion_matrix.png")

plt.show()

# %% [markdown]
# # Credit Union Loan Default Prediction
#
# This project builds a machine learning model to predict whether a borrower will default on a loan using financial and credit-related features.
#
# The workflow includes:
# - Exploratory Data Analysis
# - Correlation Analysis
# - Logistic Regression Model
# - Model Evaluation

# %% [markdown]
# ## Data Loading and Preparation
#
# The dataset is loaded using Pandas to begin the analysis.

# %% [markdown]
# ## Exploratory Data Analysis (Correlation Heatmap)
#
# A correlation heatmap is used to visualize relationships between financial variables and the loan default target variable.

# %% [markdown]
# ## Logistic Regression Model
#
# A Logistic Regression model is trained to predict loan default using borrower financial attributes.

# %% [markdown]
# ## Model Evaluation (Confusion Matrix)
#
# The confusion matrix evaluates how well the model predicts loan defaults and non-defaults.

# %% [markdown]
# ## Conclusion
# This project demonstrated how machine learning can be used to predict default risk using borrower financial attributes.
#
# Key findings:
# -Logistic Regression achieved approximately **88% accuracy**.
# -The model performs well at identifying non-default borrowers.
# -Detecting actual defaulters remains more challenging due to class imbalance.
#
# Future improvements could include testing additional models and techniques to better detect high-risk borrowers.

# %% [markdown]
# ## Random Forest Model To compare performance, a Random Forest classifier is trained to predict loan defaults using the same borrower financial features.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(n_estimators=100, random_state=42)

rf_model.fit(x_train_scaled, y_train)

rf_predictions = rf_model.predict(x_test_scaled)

# %%
from sklearn.metrics import accuracy_score

rf_accuracy = accuracy_score(y_test, rf_predictions)

print("Random Forest Accuracy:", rf_accuracy)
# Out:
# Random Forest Accuracy: 0.8859017035441551

# %% [markdown]
# ## Model Comparison
#
# Two machine learning models were trained to predict loan default:
#
# - Logistic Regression
# - Random Forest
#
# Results:
#
# - Logistic Regression Accuracy: **88.4%**
# - Random Forest Accuracy: **88.5%**
#
# Both models produced very similar performance. Random Forest slightly outperformed Logistic Regression, but the difference was minimal.
#
# This suggests the borrower financial features already capture strong predictive patterns in the dataset.

# %% [markdown]
# ## Project Summary
#
# This project explored borrower financial data to predict loan default risk.
#
# Key steps included:
# - Exploratory Data Analysis
# - Correlation Analysis
# - Logistic Regression Model
# - Random Forest Model
# - Model Evaluation using Confusion Matrix
#
# Results showed both models achieved approximately **88% prediction accuracy**, with Random Forest performing slightly better.
#
# This type of modeling is commonly used in banking and credit unions for credit risk assessment.
